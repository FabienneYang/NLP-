# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\programdata\anaconda3\lib\site-packages (3.3)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from nltk) (1.11.0)
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# You are using pip version 10.0.1, however version 20.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import pandas as pd
import nltk
#nltk.download()
import numpy as np

# %%
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Fabienne2.Yang\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %%
whole_words = set(whole_words)
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2356個單字

# %%
#建立字典使每一個單字有對應數值
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    word_index[word] = n 
    index_word[n] = word
    n+=1

# %%
word_index
# Out:
# {'somehow': 0,
#  'Salad': 1,
#  'mussels': 2,
#  'during': 3,
#  'turn': 4,
#  'man': 5,
#  'Nice': 6,
#  'wo': 7,
#  'venturing': 8,
#  'complain': 9,
#  'name': 10,
#  'website': 11,
#  'arepas': 12,
#  'thirty': 13,
#  'Shrimp-': 14,
#  'anyone': 15,
#  'unwelcome': 16,
#  'meals': 17,
#  'presentation': 18,
#  'IN': 19,
#  '.off': 20,
#  'calligraphy': 21,
#  'sandwich': 22,
#  'wire': 23,
#  'Heimer': 24,
#  'Definitely': 25,
#  'problem': 26,
#  'Stars': 27,
#  'ambiance': 28,
#  'down': 29,
#  'mozzarella': 30,
#  'got': 31,
#  'guess': 32,
#  'stale': 33,
#  'buffets': 34,
#  'seemed': 35,
#  'alone': 36,
#  'lukewarm': 37,
#  'Terrible': 38,
#  'above': 39,
#  'Left': 40,
#  'besides': 41,
#  '$': 42,
#  'fondue': 43,
#  'authentic': 44,
#  'words': 45,
#  'gotten': 46,
#  'pizza': 47,
#  'Mediocre': 48,
#  'mixed': 49,
#  'place': 50,
#  'liking': 51,
#  'HAD': 52,
#  'burgers': 53,
#  'To': 54,
#  'chefs': 55,
#  'contained': 56,
#  'frozen': 57,
#  'pictures': 58,
#  'refreshing': 59,
#  'legs': 60,
#  'corporation': 61,
#  'focused': 62,
#  'vain': 63,
#  'ourselves': 64,
#  'thick': 65,
#  'life': 66,
#  'spicy': 67,
#  'impeccable': 68,
#  'Reasonably': 69,
#  'BEST': 70,
#  'are': 71,
#  'sorely': 72,
#  'else': 73,
#  'contain': 74,
#  'brownish': 75,
#  'soundtrack': 76,
#  'slow': 77,
#  'cook': 78,
#  'salad': 79,
#  'medium': 80,
#  'dry': 81,
#  'Kabuki': 82,
#  'Unfortunately': 83,
#  'cuisine': 84,
#  'Bean': 85,
#  'head': 86,
#  'few': 87,
#  'verge': 88,
#  'because': 89,
#  'dressed': 90,
#  'combos': 91,
#  'Seat': 92,
#  'naan': 93,
#  'expect': 94,
#  'all': 95,
#  'Gourmet': 96,
#  "ya'all": 97,
#  'wrong': 98,
#  'grandmother': 99,
#  'Ians': 100,
#  'Cant': 101,
#  'hopes': 102,
#  'orders': 103,
#  'case': 104,
#  'received': 105,
#  'Coffee': 106,
#  'auju': 107,
#  'sangria': 108,
#  'atrocious': 109,
#  'Will': 110,
#  'belly': 111,
#  'something': 112,
#  'Of': 113,
#  'Francisco': 114,
#  'Steve': 115,
#  'wall': 116,
#  'AVOID': 117,
#  'ended': 118,
#  'area': 119,
#  'recommend': 120,
#  'wow': 121,
#  'upgrading': 122,
#  'enjoyable': 123,
#  'mom': 124,
#  'Taco': 125,
#  'showed': 126,
#  'wasted': 127,
#  'bites': 128,
#  'affordable': 129,
#  'weekend': 130,
#  'EVER': 131,
#  'awful': 132,
#  'fantastic': 133,
#  'Tonight': 134,
#  'breakfast': 135,
#  'Elk': 136,
#  'think': 137,
#  'extensive': 138,
#  'expectations': 139,
#  'cute': 140,
#  'entrees': 141,
#  'returning': 142,
#  'Their': 143,
#  'taco': 144,
#  'loves': 145,
#  'zero': 146,
#  'actually': 147,
#  'disaster': 148,
#  'steak': 149,
#  'signs': 150,
#  'delicioso': 151,
#  'Insults': 152,
#  'Tasty': 153,
#  'outrageously': 154,
#  '70+': 155,
#  'AYCE': 156,
#  'world': 157,
#  'non-fancy': 158,
#  'themselves': 159,
#  'Thai': 160,
#  'Gold': 161,
#  'absolutely': 162,
#  'Owner': 163,
#  'songs': 164,
#  'brunch': 165,
#  'Mary': 166,
#  'she': 167,
#  'forever': 168,
#  'crowd': 169,
#  'pile': 170,
#  'waitresses': 171,
#  'combo': 172,
#  'finally': 173,
#  '3/4ths': 174,
#  'either': 175,
#  'Sun': 176,
#  'over-whelm': 177,
#  'shawarrrrrrma': 178,
#  'older': 179,
#  'sause': 180,
#  'dime': 181,
#  'limited': 182,
#  'i': 183,
#  'drunk': 184,
#  'job': 185,
#  'thats': 186,
#  'concern': 187,
#  'up': 188,
#  'sashimi': 189,
#  'Valley': 190,
#  'RUDE': 191,
#  'home': 192,
#  'blown': 193,
#  'lawyers': 194,
#  '/hand': 195,
#  'awkwardly': 196,
#  'girlfriend': 197,
#  'refused': 198,
#  'spaghetti': 199,
#  'flavored': 200,
#  'Crema': 201,
#  'appetizer': 202,
#  'too': 203,
#  'glad': 204,
#  'Boy': 205,
#  'clue': 206,
#  'hope': 207,
#  'minutes': 208,
#  'dipping': 209,
#  'going': 210,
#  'Omelets': 211,
#  'Seriously': 212,
#  'Lordy': 213,
#  'condiment': 214,
#  'free': 215,
#  'stretch': 216,
#  'gluten': 217,
#  'food': 218,
#  'basically': 219,
#  'bite': 220,
#  'from': 221,
#  'Filet': 222,
#  'freaking': 223,
#  'staff': 224,
#  'capers': 225,
#  'array': 226,
#  'any': 227,
#  'servers': 228,
#  'how': 229,
#  'nutshell': 230,
#  'outstanding': 231,
#  'preparing': 232,
#  'crisp': 233,
#  'Café': 234,
#  'Hunan': 235,
#  'brother': 236,
#  'damn': 237,
#  'CONCLUSION': 238,
#  'Google': 239,
#  'waiting': 240,
#  'Pita': 241,
#  'things': 242,
#  'AGAIN': 243,
#  'hamburger': 244,
#  'temp.I': 245,
#  'tomato': 246,
#  'friendly': 247,
#  'delish': 248,
#  'handed': 249,
#  'oven': 250,
#  'cranberry': 251,
#  'managed': 252,
#  'sides': 253,
#  'ever': 254,
#  'difference': 255,
#  'WORST': 256,
#  'angry': 257,
#  'set': 258,
#  'gone': 259,
#  'poor': 260,
#  'cocktail': 261,
#  'Salads': 262,
#  'madhouse': 263,
#  'appealing': 264,
#  'Halibut': 265,
#  'NASTY': 266,
#  'compliments': 267,
#  'extremely': 268,
#  'TOLD': 269,
#  'months': 270,
#  'though': 271,
#  'baklava': 272,
#  'enjoy': 273,
#  'describing': 274,
#  'menu/': 275,
#  'bye': 276,
#  'version': 277,
#  'glance': 278,
#  'boy': 279,
#  'sucked': 280,
#  'Things': 281,
#  'reasonably': 282,
#  'in-house': 283,
#  'terrific': 284,
#  '35': 285,
#  'oh': 286,
#  '..ohhh': 287,
#  'did': 288,
#  'bathroom': 289,
#  'ordering': 290,
#  'ESTABLISHMENT': 291,
#  'surprise': 292,
#  'Poor': 293,
#  'funny': 294,
#  'creamy': 295,
#  "'s": 296,
#  'tepid': 297,
#  'delicate': 298,
#  'flair': 299,
#  'evening': 300,
#  'Great': 301,
#  'fill': 302,
#  '&': 303,
#  'Sprouts': 304,
#  "''": 305,
#  'requested': 306,
#  'That': 307,
#  'acknowledged': 308,
#  'lost': 309,
#  'TIME': 310,
#  'pepper': 311,
#  'restaurant': 312,
#  'shops': 313,
#  'expanded': 314,
#  'waited': 315,
#  'potato': 316,
#  'cool': 317,
#  'stuffed': 318,
#  'mile': 319,
#  'pats': 320,
#  'coziness': 321,
#  'after': 322,
#  'beautiful': 323,
#  'cake': 324,
#  'Noca': 325,
#  'anymore': 326,
#  'No': 327,
#  'Tasted': 328,
#  'Big': 329,
#  'shall': 330,
#  'court': 331,
#  'Always': 332,
#  'sub-par': 333,
#  'lady': 334,
#  'mostly': 335,
#  'old': 336,
#  'into': 337,
#  'wrap': 338,
#  'prices': 339,
#  'been-stepped-in-and-tracked-everywhere': 340,
#  'imagine': 341,
#  'Have': 342,
#  'Do': 343,
#  'tell': 344,
#  'nut': 345,
#  'providing': 346,
#  'homemade': 347,
#  'Wife': 348,
#  'drive': 349,
#  'THAT': 350,
#  'everyone': 351,
#  '40min': 352,
#  'went': 353,
#  'stupid': 354,
#  'theft': 355,
#  'yet': 356,
#  'Greek': 357,
#  'North': 358,
#  'time': 359,
#  'Phoenix': 360,
#  'recent': 361,
#  'night': 362,
#  'Place': 363,
#  'multiple': 364,
#  'supposed': 365,
#  'hoping': 366,
#  'itself': 367,
#  'raspberry': 368,
#  'Firehouse': 369,
#  'low-key': 370,
#  'yourself': 371,
#  'inexpensive': 372,
#  'Experience': 373,
#  'before': 374,
#  'soon': 375,
#  'Seafood': 376,
#  'neighborhood': 377,
#  'plate': 378,
#  'accident': 379,
#  'live': 380,
#  'disbelief': 381,
#  'beer': 382,
#  'suck': 383,
#  'you': 384,
#  'clean': 385,
#  'receives': 386,
#  'heads': 387,
#  'believe': 388,
#  'lovely': 389,
#  'OK': 390,
#  'music': 391,
#  'Disappointing': 392,
#  'closed': 393,
#  'And': 394,
#  '``': 395,
#  'great': 396,
#  'bacon': 397,
#  'biscuits': 398,
#  'correct': 399,
#  'considering': 400,
#  'bus': 401,
#  'greens': 402,
#  'stayed': 403,
#  'Ryan': 404,
#  'kitchen': 405,
#  'unbelievably': 406,
#  'Mom': 407,
#  'deuchebaggery': 408,
#  'Ninja': 409,
#  'Soggy': 410,
#  'legit': 411,
#  'golden-crispy': 412,
#  'goat': 413,
#  'super': 414,
#  'disappoint': 415,
#  'cart': 416,
#  'selection': 417,
#  'Waiter': 418,
#  'breakfast/lunch': 419,
#  'pan': 420,
#  'tip': 421,
#  'item': 422,
#  'Took': 423,
#  'brings': 424,
#  'teamwork': 425,
#  'rich': 426,
#  'eggs': 427,
#  'These': 428,
#  'driest': 429,
#  'steakhouse': 430,
#  'flavors': 431,
#  'relationship': 432,
#  'tartare': 433,
#  'Macarons': 434,
#  'incredible': 435,
#  'ahead': 436,
#  'longer': 437,
#  'rolls': 438,
#  'seasonal': 439,
#  'genuinely': 440,
#  '1/2': 441,
#  'his': 442,
#  'wonderful': 443,
#  'Spend': 444,
#  'gas': 445,
#  'pecan': 446,
#  'bit': 447,
#  'where': 448,
#  'Hard': 449,
#  'promise': 450,
#  'cow': 451,
#  'location': 452,
#  'perpared': 453,
#  'IT': 454,
#  'Flower': 455,
#  'egg': 456,
#  'excuse': 457,
#  'again': 458,
#  'parties': 459,
#  'outta': 460,
#  'hooked': 461,
#  'found': 462,
#  "n't": 463,
#  'Pizza': 464,
#  'helped': 465,
#  'eat': 466,
#  'Chipotle': 467,
#  'guests': 468,
#  'NO': 469,
#  'despicable': 470,
#  'helpful': 471,
#  'plantains': 472,
#  'STALE': 473,
#  'Just': 474,
#  'sit-down': 475,
#  'Tucson': 476,
#  'honest': 477,
#  'five': 478,
#  'perfection': 479,
#  'feels': 480,
#  'selections': 481,
#  'Paradise': 482,
#  'Cape': 483,
#  'promptly': 484,
#  'guy': 485,
#  'rolled': 486,
#  'unwrapped': 487,
#  'EXPERIENCE': 488,
#  'Also': 489,
#  'sitting': 490,
#  'Special': 491,
#  'overcooked': 492,
#  'Hawaiian': 493,
#  'Eew': 494,
#  'added': 495,
#  'pretty': 496,
#  'delights': 497,
#  'Egg': 498,
#  'foods': 499,
#  'Thoroughly': 500,
#  'At': 501,
#  '..went': 502,
#  'curry': 503,
#  'must': 504,
#  'Your': 505,
#  'caught': 506,
#  'made': 507,
#  'prefer': 508,
#  'MUST': 509,
#  'metro': 510,
#  'devine': 511,
#  '8': 512,
#  'Cotta': 513,
#  'The': 514,
#  'even': 515,
#  'Appetite': 516,
#  'Frenchman': 517,
#  'staying': 518,
#  'cashew': 519,
#  'grease': 520,
#  'tapas': 521,
#  'Mexican': 522,
#  'barely': 523,
#  'between': 524,
#  'Buffet': 525,
#  'help': 526,
#  '10+': 527,
#  'small': 528,
#  'cold': 529,
#  'thing': 530,
#  'app': 531,
#  'Back': 532,
#  'fucking': 533,
#  'stood': 534,
#  'doing': 535,
#  'bring': 536,
#  '-Drinks': 537,
#  'truly': 538,
#  'sure': 539,
#  'If': 540,
#  'say': 541,
#  'avoid': 542,
#  'patio': 543,
#  'grow': 544,
#  'bakery': 545,
#  'away': 546,
#  'disagree': 547,
#  'sauce': 548,
#  'Hopefully': 549,
#  'ribeye': 550,
#  'does': 551,
#  'by': 552,
#  'Strip': 553,
#  'Ramsey': 554,
#  'hungry': 555,
#  'eyed': 556,
#  'event': 557,
#  'gloves.Everything': 558,
#  'pho': 559,
#  'pancakes': 560,
#  'tailored': 561,
#  'Level': 562,
#  'located': 563,
#  'mesquite': 564,
#  'Furthermore': 565,
#  'Mango': 566,
#  'Scottsdale': 567,
#  'establishment': 568,
#  'sweet': 569,
#  'house': 570,
#  'meat': 571,
#  'After': 572,
#  'Tigerlilly': 573,
#  'Italian': 574,
#  'dirty': 575,
#  'swung': 576,
#  'burned': 577,
#  'A': 578,
#  'BACK': 579,
#  '*heart*': 580,
#  'Nargile': 581,
#  'latte': 582,
#  'mortified': 583,
#  'little': 584,
#  'quite': 585,
#  'favorite': 586,
#  'poured': 587,
#  'shower': 588,
#  'trips': 589,
#  'carbs': 590,
#  'third': 591,
#  'corn': 592,
#  'has': 593,
#  'Dog': 594,
#  'Christmas': 595,
#  'roast': 596,
#  'undercooked': 597,
#  'picture': 598,
#  'fellow': 599,
#  'desserts': 600,
#  'most': 601,
#  'section': 602,
#  'party': 603,
#  'luck': 604,
#  'daughter': 605,
#  'saffron': 606,
#  'walked': 607,
#  'Would': 608,
#  'walls': 609,
#  'absolutley': 610,
#  'have': 611,
#  'last': 612,
#  'familiar': 613,
#  'tartar': 614,
#  'Shop': 615,
#  'brought': 616,
#  'Friend': 617,
#  'crumby': 618,
#  'highlighted': 619,
#  'their': 620,
#  'TOTAL': 621,
#  'OVERPRICED': 622,
#  'carpaccio': 623,
#  'sharply': 624,
#  'round': 625,
#  'lighter': 626,
#  '90': 627,
#  'soooo': 628,
#  'smoothies': 629,
#  'NEVER': 630,
#  'the': 631,
#  'Update': 632,
#  'hi': 633,
#  'rave': 634,
#  'options': 635,
#  'Honestly': 636,
#  'pissd': 637,
#  'profiterole': 638,
#  'WEAK': 639,
#  'no': 640,
#  'customize': 641,
#  'loudly': 642,
#  'uploaded': 643,
#  'beers': 644,
#  'tenders': 645,
#  'look': 646,
#  'date': 647,
#  'duck': 648,
#  '!': 649,
#  'enjoyed': 650,
#  'spends': 651,
#  'turkey': 652,
#  'effort': 653,
#  'ice': 654,
#  'hole': 655,
#  'violinists': 656,
#  'dripping': 657,
#  'via': 658,
#  'cause': 659,
#  'mood': 660,
#  'Eve': 661,
#  'Service': 662,
#  'or': 663,
#  'year': 664,
#  'law': 665,
#  'setting': 666,
#  'care': 667,
#  'Burrittos': 668,
#  'iced': 669,
#  'charcoal': 670,
#  'asked': 671,
#  'without': 672,
#  'trap': 673,
#  'ten': 674,
#  'relleno': 675,
#  'Frozen': 676,
#  'seated': 677,
#  'Anyways': 678,
#  'yay': 679,
#  'judge': 680,
#  'color': 681,
#  'consistent': 682,
#  'Love': 683,
#  'dough': 684,
#  'Madison': 685,
#  'lots': 686,
#  'blue': 687,
#  'tea': 688,
#  'Up': 689,
#  'hummus': 690,
#  'approval': 691,
#  'literally': 692,
#  'Service-check': 693,
#  'lacking': 694,
#  'tender': 695,
#  'etc': 696,
#  'reservation': 697,
#  'atmosphere.1': 698,
#  'relaxed': 699,
#  'with': 700,
#  'sushi': 701,
#  'chewy': 702,
#  'held': 703,
#  'BARE': 704,
#  'crusty': 705,
#  'somewhat': 706,
#  'descriptions': 707,
#  'tummy': 708,
#  'hilarious': 709,
#  'sexy': 710,
#  'Han': 711,
#  'its': 712,
#  'cash': 713,
#  'six': 714,
#  'Mellow': 715,
#  'dealing': 716,
#  'list': 717,
#  'pleasure': 718,
#  'elegantly': 719,
#  'special': 720,
#  'expensive': 721,
#  'least': 722,
#  'behind': 723,
#  'WILL': 724,
#  'Crostini': 725,
#  'treat': 726,
#  'dispenser': 727,
#  'Despite': 728,
#  'dog': 729,
#  'loving': 730,
#  'Are': 731,
#  'taste': 732,
#  'However': 733,
#  'price': 734,
#  'best': 735,
#  "'": 736,
#  'Luke': 737,
#  'warm': 738,
#  'seafood': 739,
#  'stop': 740,
#  'olives': 741,
#  'begin': 742,
#  'need': 743,
#  'crepe': 744,
#  'Subway': 745,
#  'placed': 746,
#  'petty': 747,
#  'bars': 748,
#  'Hiro': 749,
#  'tiramisu': 750,
#  'quit': 751,
#  'must-stop': 752,
#  '.THE': 753,
#  'nay': 754,
#  'transcendant': 755,
#  'impressed': 756,
#  'inflate': 757,
#  'portion': 758,
#  'dark': 759,
#  'Favorite': 760,
#  'pay': 761,
#  'whether': 762,
#  'pop': 763,
#  'big': 764,
#  'every': 765,
#  'PEOPLE': 766,
#  'hottest': 767,
#  'Everything': 768,
#  'can': 769,
#  'occasions': 770,
#  'truffle': 771,
#  'patty': 772,
#  'Went': 773,
#  'climbing': 774,
#  'RI': 775,
#  'fuzzy': 776,
#  'welcome': 777,
#  'crust': 778,
#  'tastings': 779,
#  'Mediterranean': 780,
#  'experienced': 781,
#  'find': 782,
#  'High-quality': 783,
#  'ordered': 784,
#  'Waited': 785,
#  'onion': 786,
#  'easily': 787,
#  'T.': 788,
#  'living': 789,
#  'Bay': 790,
#  'hearts': 791,
#  'check': 792,
#  'kid': 793,
#  'me': 794,
#  'but': 795,
#  'comfortable': 796,
#  'Ordered': 797,
#  'dinner': 798,
#  'bloodiest': 799,
#  'Japanese': 800,
#  'drastically': 801,
#  'bigger': 802,
#  'giving': 803,
#  'Ha': 804,
#  'well': 805,
#  'happier': 806,
#  'us': 807,
#  ',': 808,
#  'mind': 809,
#  'exactly': 810,
#  '23': 811,
#  'yummy': 812,
#  'Large': 813,
#  'AZ': 814,
#  'beauty': 815,
#  'humiliated': 816,
#  'ravoli': 817,
#  'cooked': 818,
#  'edible': 819,
#  'usual': 820,
#  'Ample': 821,
#  'highly': 822,
#  'simply': 823,
#  'deal': 824,
#  'different': 825,
#  'generic': 826,
#  'money': 827,
#  'crazy': 828,
#  'southwest': 829,
#  'worries': 830,
#  'restaurants': 831,
#  'around': 832,
#  'slaw': 833,
#  'Breeze': 834,
#  'family': 835,
#  'voted': 836,
#  'hand': 837,
#  'degree': 838,
#  'Thus': 839,
#  'looks': 840,
#  'Hell': 841,
#  'rapidly': 842,
#  'rushed': 843,
#  'in': 844,
#  'Those': 845,
#  'store': 846,
#  'than': 847,
#  'Best': 848,
#  'Now': 849,
#  'fat': 850,
#  'Which': 851,
#  'places': 852,
#  'Every': 853,
#  'salmon': 854,
#  'Im': 855,
#  'Before': 856,
#  'handmade': 857,
#  'ignore': 858,
#  'businesses': 859,
#  'honestly': 860,
#  'services': 861,
#  'boring': 862,
#  'Otto': 863,
#  'biscuit': 864,
#  'tuna': 865,
#  'events': 866,
#  'low': 867,
#  'pulled': 868,
#  'sliced': 869,
#  'gooodd': 870,
#  'garlic': 871,
#  'courteous': 872,
#  'perfect': 873,
#  'fries': 874,
#  'cheap': 875,
#  'Nicest': 876,
#  'loyal': 877,
#  'plain': 878,
#  'Perfect': 879,
#  'high': 880,
#  'running': 881,
#  'piece': 882,
#  'joint': 883,
#  'Blah': 884,
#  'sporting': 885,
#  'NOW': 886,
#  'class': 887,
#  'shoots': 888,
#  'highlights': 889,
#  'cheated': 890,
#  'bathrooms': 891,
#  'rest': 892,
#  'Food': 893,
#  'gristle': 894,
#  'appetizers': 895,
#  'shirt': 896,
#  'Sour': 897,
#  'yukon': 898,
#  'accomodate': 899,
#  'generous': 900,
#  'My': 901,
#  'relocated': 902,
#  'entire': 903,
#  'let': 904,
#  'peanuts': 905,
#  'fireball': 906,
#  'sucks': 907,
#  'looked': 908,
#  'bruschetta': 909,
#  'obviously': 910,
#  'Prices': 911,
#  'par': 912,
#  'Philadelphia': 913,
#  'papers': 914,
#  'pasta': 915,
#  'Cibo': 916,
#  'From': 917,
#  'May': 918,
#  'pumpkin': 919,
#  'MGM': 920,
#  'struck': 921,
#  'Albondigas': 922,
#  'point': 923,
#  '1.5lb': 924,
#  'dirt': 925,
#  'fell': 926,
#  'beef': 927,
#  'haunt': 928,
#  '%': 929,
#  'Damn': 930,
#  'order': 931,
#  'lil': 932,
#  'Gave': 933,
#  'This': 934,
#  'Avoid': 935,
#  'imagined': 936,
#  '.': 937,
#  'Each': 938,
#  'AN': 939,
#  'melted': 940,
#  'juice..': 941,
#  'meh': 942,
#  'die': 943,
#  'enthusiastic': 944,
#  'seating': 945,
#  'sandwiches': 946,
#  'Interesting': 947,
#  'waiter': 948,
#  'officially': 949,
#  'food/service': 950,
#  'liked': 951,
#  'Magazine': 952,
#  'door': 953,
#  'takeout': 954,
#  'deliciously': 955,
#  'box': 956,
#  'street': 957,
#  'lacked': 958,
#  'fairly': 959,
#  'flavourful': 960,
#  'Maine': 961,
#  'packed': 962,
#  'parents': 963,
#  'Try': 964,
#  'about': 965,
#  'Smashburger': 966,
#  'attack': 967,
#  'her': 968,
#  'pleased': 969,
#  'appalling': 970,
#  'stars': 971,
#  'bone': 972,
#  'spinach': 973,
#  '15': 974,
#  'patron': 975,
#  'dish': 976,
#  'An': 977,
#  'outside': 978,
#  'HOUR': 979,
#  'correction': 980,
#  'Dessert': 981,
#  'All': 982,
#  'Excalibur': 983,
#  'town': 984,
#  'excellent': 985,
#  'toasted': 986,
#  'both': 987,
#  'sugary': 988,
#  'Plater': 989,
#  'play': 990,
#  'lettuce': 991,
#  'forth': 992,
#  'Only': 993,
#  'Mirage': 994,
#  'could': 995,
#  'Mmmm': 996,
#  'out': 997,
#  'meatballs': 998,
#  'under': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'somehow',
#  1: 'Salad',
#  2: 'mussels',
#  3: 'during',
#  4: 'turn',
#  5: 'man',
#  6: 'Nice',
#  7: 'wo',
#  8: 'venturing',
#  9: 'complain',
#  10: 'name',
#  11: 'website',
#  12: 'arepas',
#  13: 'thirty',
#  14: 'Shrimp-',
#  15: 'anyone',
#  16: 'unwelcome',
#  17: 'meals',
#  18: 'presentation',
#  19: 'IN',
#  20: '.off',
#  21: 'calligraphy',
#  22: 'sandwich',
#  23: 'wire',
#  24: 'Heimer',
#  25: 'Definitely',
#  26: 'problem',
#  27: 'Stars',
#  28: 'ambiance',
#  29: 'down',
#  30: 'mozzarella',
#  31: 'got',
#  32: 'guess',
#  33: 'stale',
#  34: 'buffets',
#  35: 'seemed',
#  36: 'alone',
#  37: 'lukewarm',
#  38: 'Terrible',
#  39: 'above',
#  40: 'Left',
#  41: 'besides',
#  42: '$',
#  43: 'fondue',
#  44: 'authentic',
#  45: 'words',
#  46: 'gotten',
#  47: 'pizza',
#  48: 'Mediocre',
#  49: 'mixed',
#  50: 'place',
#  51: 'liking',
#  52: 'HAD',
#  53: 'burgers',
#  54: 'To',
#  55: 'chefs',
#  56: 'contained',
#  57: 'frozen',
#  58: 'pictures',
#  59: 'refreshing',
#  60: 'legs',
#  61: 'corporation',
#  62: 'focused',
#  63: 'vain',
#  64: 'ourselves',
#  65: 'thick',
#  66: 'life',
#  67: 'spicy',
#  68: 'impeccable',
#  69: 'Reasonably',
#  70: 'BEST',
#  71: 'are',
#  72: 'sorely',
#  73: 'else',
#  74: 'contain',
#  75: 'brownish',
#  76: 'soundtrack',
#  77: 'slow',
#  78: 'cook',
#  79: 'salad',
#  80: 'medium',
#  81: 'dry',
#  82: 'Kabuki',
#  83: 'Unfortunately',
#  84: 'cuisine',
#  85: 'Bean',
#  86: 'head',
#  87: 'few',
#  88: 'verge',
#  89: 'because',
#  90: 'dressed',
#  91: 'combos',
#  92: 'Seat',
#  93: 'naan',
#  94: 'expect',
#  95: 'all',
#  96: 'Gourmet',
#  97: "ya'all",
#  98: 'wrong',
#  99: 'grandmother',
#  100: 'Ians',
#  101: 'Cant',
#  102: 'hopes',
#  103: 'orders',
#  104: 'case',
#  105: 'received',
#  106: 'Coffee',
#  107: 'auju',
#  108: 'sangria',
#  109: 'atrocious',
#  110: 'Will',
#  111: 'belly',
#  112: 'something',
#  113: 'Of',
#  114: 'Francisco',
#  115: 'Steve',
#  116: 'wall',
#  117: 'AVOID',
#  118: 'ended',
#  119: 'area',
#  120: 'recommend',
#  121: 'wow',
#  122: 'upgrading',
#  123: 'enjoyable',
#  124: 'mom',
#  125: 'Taco',
#  126: 'showed',
#  127: 'wasted',
#  128: 'bites',
#  129: 'affordable',
#  130: 'weekend',
#  131: 'EVER',
#  132: 'awful',
#  133: 'fantastic',
#  134: 'Tonight',
#  135: 'breakfast',
#  136: 'Elk',
#  137: 'think',
#  138: 'extensive',
#  139: 'expectations',
#  140: 'cute',
#  141: 'entrees',
#  142: 'returning',
#  143: 'Their',
#  144: 'taco',
#  145: 'loves',
#  146: 'zero',
#  147: 'actually',
#  148: 'disaster',
#  149: 'steak',
#  150: 'signs',
#  151: 'delicioso',
#  152: 'Insults',
#  153: 'Tasty',
#  154: 'outrageously',
#  155: '70+',
#  156: 'AYCE',
#  157: 'world',
#  158: 'non-fancy',
#  159: 'themselves',
#  160: 'Thai',
#  161: 'Gold',
#  162: 'absolutely',
#  163: 'Owner',
#  164: 'songs',
#  165: 'brunch',
#  166: 'Mary',
#  167: 'she',
#  168: 'forever',
#  169: 'crowd',
#  170: 'pile',
#  171: 'waitresses',
#  172: 'combo',
#  173: 'finally',
#  174: '3/4ths',
#  175: 'either',
#  176: 'Sun',
#  177: 'over-whelm',
#  178: 'shawarrrrrrma',
#  179: 'older',
#  180: 'sause',
#  181: 'dime',
#  182: 'limited',
#  183: 'i',
#  184: 'drunk',
#  185: 'job',
#  186: 'thats',
#  187: 'concern',
#  188: 'up',
#  189: 'sashimi',
#  190: 'Valley',
#  191: 'RUDE',
#  192: 'home',
#  193: 'blown',
#  194: 'lawyers',
#  195: '/hand',
#  196: 'awkwardly',
#  197: 'girlfriend',
#  198: 'refused',
#  199: 'spaghetti',
#  200: 'flavored',
#  201: 'Crema',
#  202: 'appetizer',
#  203: 'too',
#  204: 'glad',
#  205: 'Boy',
#  206: 'clue',
#  207: 'hope',
#  208: 'minutes',
#  209: 'dipping',
#  210: 'going',
#  211: 'Omelets',
#  212: 'Seriously',
#  213: 'Lordy',
#  214: 'condiment',
#  215: 'free',
#  216: 'stretch',
#  217: 'gluten',
#  218: 'food',
#  219: 'basically',
#  220: 'bite',
#  221: 'from',
#  222: 'Filet',
#  223: 'freaking',
#  224: 'staff',
#  225: 'capers',
#  226: 'array',
#  227: 'any',
#  228: 'servers',
#  229: 'how',
#  230: 'nutshell',
#  231: 'outstanding',
#  232: 'preparing',
#  233: 'crisp',
#  234: 'Café',
#  235: 'Hunan',
#  236: 'brother',
#  237: 'damn',
#  238: 'CONCLUSION',
#  239: 'Google',
#  240: 'waiting',
#  241: 'Pita',
#  242: 'things',
#  243: 'AGAIN',
#  244: 'hamburger',
#  245: 'temp.I',
#  246: 'tomato',
#  247: 'friendly',
#  248: 'delish',
#  249: 'handed',
#  250: 'oven',
#  251: 'cranberry',
#  252: 'managed',
#  253: 'sides',
#  254: 'ever',
#  255: 'difference',
#  256: 'WORST',
#  257: 'angry',
#  258: 'set',
#  259: 'gone',
#  260: 'poor',
#  261: 'cocktail',
#  262: 'Salads',
#  263: 'madhouse',
#  264: 'appealing',
#  265: 'Halibut',
#  266: 'NASTY',
#  267: 'compliments',
#  268: 'extremely',
#  269: 'TOLD',
#  270: 'months',
#  271: 'though',
#  272: 'baklava',
#  273: 'enjoy',
#  274: 'describing',
#  275: 'menu/',
#  276: 'bye',
#  277: 'version',
#  278: 'glance',
#  279: 'boy',
#  280: 'sucked',
#  281: 'Things',
#  282: 'reasonably',
#  283: 'in-house',
#  284: 'terrific',
#  285: '35',
#  286: 'oh',
#  287: '..ohhh',
#  288: 'did',
#  289: 'bathroom',
#  290: 'ordering',
#  291: 'ESTABLISHMENT',
#  292: 'surprise',
#  293: 'Poor',
#  294: 'funny',
#  295: 'creamy',
#  296: "'s",
#  297: 'tepid',
#  298: 'delicate',
#  299: 'flair',
#  300: 'evening',
#  301: 'Great',
#  302: 'fill',
#  303: '&',
#  304: 'Sprouts',
#  305: "''",
#  306: 'requested',
#  307: 'That',
#  308: 'acknowledged',
#  309: 'lost',
#  310: 'TIME',
#  311: 'pepper',
#  312: 'restaurant',
#  313: 'shops',
#  314: 'expanded',
#  315: 'waited',
#  316: 'potato',
#  317: 'cool',
#  318: 'stuffed',
#  319: 'mile',
#  320: 'pats',
#  321: 'coziness',
#  322: 'after',
#  323: 'beautiful',
#  324: 'cake',
#  325: 'Noca',
#  326: 'anymore',
#  327: 'No',
#  328: 'Tasted',
#  329: 'Big',
#  330: 'shall',
#  331: 'court',
#  332: 'Always',
#  333: 'sub-par',
#  334: 'lady',
#  335: 'mostly',
#  336: 'old',
#  337: 'into',
#  338: 'wrap',
#  339: 'prices',
#  340: 'been-stepped-in-and-tracked-everywhere',
#  341: 'imagine',
#  342: 'Have',
#  343: 'Do',
#  344: 'tell',
#  345: 'nut',
#  346: 'providing',
#  347: 'homemade',
#  348: 'Wife',
#  349: 'drive',
#  350: 'THAT',
#  351: 'everyone',
#  352: '40min',
#  353: 'went',
#  354: 'stupid',
#  355: 'theft',
#  356: 'yet',
#  357: 'Greek',
#  358: 'North',
#  359: 'time',
#  360: 'Phoenix',
#  361: 'recent',
#  362: 'night',
#  363: 'Place',
#  364: 'multiple',
#  365: 'supposed',
#  366: 'hoping',
#  367: 'itself',
#  368: 'raspberry',
#  369: 'Firehouse',
#  370: 'low-key',
#  371: 'yourself',
#  372: 'inexpensive',
#  373: 'Experience',
#  374: 'before',
#  375: 'soon',
#  376: 'Seafood',
#  377: 'neighborhood',
#  378: 'plate',
#  379: 'accident',
#  380: 'live',
#  381: 'disbelief',
#  382: 'beer',
#  383: 'suck',
#  384: 'you',
#  385: 'clean',
#  386: 'receives',
#  387: 'heads',
#  388: 'believe',
#  389: 'lovely',
#  390: 'OK',
#  391: 'music',
#  392: 'Disappointing',
#  393: 'closed',
#  394: 'And',
#  395: '``',
#  396: 'great',
#  397: 'bacon',
#  398: 'biscuits',
#  399: 'correct',
#  400: 'considering',
#  401: 'bus',
#  402: 'greens',
#  403: 'stayed',
#  404: 'Ryan',
#  405: 'kitchen',
#  406: 'unbelievably',
#  407: 'Mom',
#  408: 'deuchebaggery',
#  409: 'Ninja',
#  410: 'Soggy',
#  411: 'legit',
#  412: 'golden-crispy',
#  413: 'goat',
#  414: 'super',
#  415: 'disappoint',
#  416: 'cart',
#  417: 'selection',
#  418: 'Waiter',
#  419: 'breakfast/lunch',
#  420: 'pan',
#  421: 'tip',
#  422: 'item',
#  423: 'Took',
#  424: 'brings',
#  425: 'teamwork',
#  426: 'rich',
#  427: 'eggs',
#  428: 'These',
#  429: 'driest',
#  430: 'steakhouse',
#  431: 'flavors',
#  432: 'relationship',
#  433: 'tartare',
#  434: 'Macarons',
#  435: 'incredible',
#  436: 'ahead',
#  437: 'longer',
#  438: 'rolls',
#  439: 'seasonal',
#  440: 'genuinely',
#  441: '1/2',
#  442: 'his',
#  443: 'wonderful',
#  444: 'Spend',
#  445: 'gas',
#  446: 'pecan',
#  447: 'bit',
#  448: 'where',
#  449: 'Hard',
#  450: 'promise',
#  451: 'cow',
#  452: 'location',
#  453: 'perpared',
#  454: 'IT',
#  455: 'Flower',
#  456: 'egg',
#  457: 'excuse',
#  458: 'again',
#  459: 'parties',
#  460: 'outta',
#  461: 'hooked',
#  462: 'found',
#  463: "n't",
#  464: 'Pizza',
#  465: 'helped',
#  466: 'eat',
#  467: 'Chipotle',
#  468: 'guests',
#  469: 'NO',
#  470: 'despicable',
#  471: 'helpful',
#  472: 'plantains',
#  473: 'STALE',
#  474: 'Just',
#  475: 'sit-down',
#  476: 'Tucson',
#  477: 'honest',
#  478: 'five',
#  479: 'perfection',
#  480: 'feels',
#  481: 'selections',
#  482: 'Paradise',
#  483: 'Cape',
#  484: 'promptly',
#  485: 'guy',
#  486: 'rolled',
#  487: 'unwrapped',
#  488: 'EXPERIENCE',
#  489: 'Also',
#  490: 'sitting',
#  491: 'Special',
#  492: 'overcooked',
#  493: 'Hawaiian',
#  494: 'Eew',
#  495: 'added',
#  496: 'pretty',
#  497: 'delights',
#  498: 'Egg',
#  499: 'foods',
#  500: 'Thoroughly',
#  501: 'At',
#  502: '..went',
#  503: 'curry',
#  504: 'must',
#  505: 'Your',
#  506: 'caught',
#  507: 'made',
#  508: 'prefer',
#  509: 'MUST',
#  510: 'metro',
#  511: 'devine',
#  512: '8',
#  513: 'Cotta',
#  514: 'The',
#  515: 'even',
#  516: 'Appetite',
#  517: 'Frenchman',
#  518: 'staying',
#  519: 'cashew',
#  520: 'grease',
#  521: 'tapas',
#  522: 'Mexican',
#  523: 'barely',
#  524: 'between',
#  525: 'Buffet',
#  526: 'help',
#  527: '10+',
#  528: 'small',
#  529: 'cold',
#  530: 'thing',
#  531: 'app',
#  532: 'Back',
#  533: 'fucking',
#  534: 'stood',
#  535: 'doing',
#  536: 'bring',
#  537: '-Drinks',
#  538: 'truly',
#  539: 'sure',
#  540: 'If',
#  541: 'say',
#  542: 'avoid',
#  543: 'patio',
#  544: 'grow',
#  545: 'bakery',
#  546: 'away',
#  547: 'disagree',
#  548: 'sauce',
#  549: 'Hopefully',
#  550: 'ribeye',
#  551: 'does',
#  552: 'by',
#  553: 'Strip',
#  554: 'Ramsey',
#  555: 'hungry',
#  556: 'eyed',
#  557: 'event',
#  558: 'gloves.Everything',
#  559: 'pho',
#  560: 'pancakes',
#  561: 'tailored',
#  562: 'Level',
#  563: 'located',
#  564: 'mesquite',
#  565: 'Furthermore',
#  566: 'Mango',
#  567: 'Scottsdale',
#  568: 'establishment',
#  569: 'sweet',
#  570: 'house',
#  571: 'meat',
#  572: 'After',
#  573: 'Tigerlilly',
#  574: 'Italian',
#  575: 'dirty',
#  576: 'swung',
#  577: 'burned',
#  578: 'A',
#  579: 'BACK',
#  580: '*heart*',
#  581: 'Nargile',
#  582: 'latte',
#  583: 'mortified',
#  584: 'little',
#  585: 'quite',
#  586: 'favorite',
#  587: 'poured',
#  588: 'shower',
#  589: 'trips',
#  590: 'carbs',
#  591: 'third',
#  592: 'corn',
#  593: 'has',
#  594: 'Dog',
#  595: 'Christmas',
#  596: 'roast',
#  597: 'undercooked',
#  598: 'picture',
#  599: 'fellow',
#  600: 'desserts',
#  601: 'most',
#  602: 'section',
#  603: 'party',
#  604: 'luck',
#  605: 'daughter',
#  606: 'saffron',
#  607: 'walked',
#  608: 'Would',
#  609: 'walls',
#  610: 'absolutley',
#  611: 'have',
#  612: 'last',
#  613: 'familiar',
#  614: 'tartar',
#  615: 'Shop',
#  616: 'brought',
#  617: 'Friend',
#  618: 'crumby',
#  619: 'highlighted',
#  620: 'their',
#  621: 'TOTAL',
#  622: 'OVERPRICED',
#  623: 'carpaccio',
#  624: 'sharply',
#  625: 'round',
#  626: 'lighter',
#  627: '90',
#  628: 'soooo',
#  629: 'smoothies',
#  630: 'NEVER',
#  631: 'the',
#  632: 'Update',
#  633: 'hi',
#  634: 'rave',
#  635: 'options',
#  636: 'Honestly',
#  637: 'pissd',
#  638: 'profiterole',
#  639: 'WEAK',
#  640: 'no',
#  641: 'customize',
#  642: 'loudly',
#  643: 'uploaded',
#  644: 'beers',
#  645: 'tenders',
#  646: 'look',
#  647: 'date',
#  648: 'duck',
#  649: '!',
#  650: 'enjoyed',
#  651: 'spends',
#  652: 'turkey',
#  653: 'effort',
#  654: 'ice',
#  655: 'hole',
#  656: 'violinists',
#  657: 'dripping',
#  658: 'via',
#  659: 'cause',
#  660: 'mood',
#  661: 'Eve',
#  662: 'Service',
#  663: 'or',
#  664: 'year',
#  665: 'law',
#  666: 'setting',
#  667: 'care',
#  668: 'Burrittos',
#  669: 'iced',
#  670: 'charcoal',
#  671: 'asked',
#  672: 'without',
#  673: 'trap',
#  674: 'ten',
#  675: 'relleno',
#  676: 'Frozen',
#  677: 'seated',
#  678: 'Anyways',
#  679: 'yay',
#  680: 'judge',
#  681: 'color',
#  682: 'consistent',
#  683: 'Love',
#  684: 'dough',
#  685: 'Madison',
#  686: 'lots',
#  687: 'blue',
#  688: 'tea',
#  689: 'Up',
#  690: 'hummus',
#  691: 'approval',
#  692: 'literally',
#  693: 'Service-check',
#  694: 'lacking',
#  695: 'tender',
#  696: 'etc',
#  697: 'reservation',
#  698: 'atmosphere.1',
#  699: 'relaxed',
#  700: 'with',
#  701: 'sushi',
#  702: 'chewy',
#  703: 'held',
#  704: 'BARE',
#  705: 'crusty',
#  706: 'somewhat',
#  707: 'descriptions',
#  708: 'tummy',
#  709: 'hilarious',
#  710: 'sexy',
#  711: 'Han',
#  712: 'its',
#  713: 'cash',
#  714: 'six',
#  715: 'Mellow',
#  716: 'dealing',
#  717: 'list',
#  718: 'pleasure',
#  719: 'elegantly',
#  720: 'special',
#  721: 'expensive',
#  722: 'least',
#  723: 'behind',
#  724: 'WILL',
#  725: 'Crostini',
#  726: 'treat',
#  727: 'dispenser',
#  728: 'Despite',
#  729: 'dog',
#  730: 'loving',
#  731: 'Are',
#  732: 'taste',
#  733: 'However',
#  734: 'price',
#  735: 'best',
#  736: "'",
#  737: 'Luke',
#  738: 'warm',
#  739: 'seafood',
#  740: 'stop',
#  741: 'olives',
#  742: 'begin',
#  743: 'need',
#  744: 'crepe',
#  745: 'Subway',
#  746: 'placed',
#  747: 'petty',
#  748: 'bars',
#  749: 'Hiro',
#  750: 'tiramisu',
#  751: 'quit',
#  752: 'must-stop',
#  753: '.THE',
#  754: 'nay',
#  755: 'transcendant',
#  756: 'impressed',
#  757: 'inflate',
#  758: 'portion',
#  759: 'dark',
#  760: 'Favorite',
#  761: 'pay',
#  762: 'whether',
#  763: 'pop',
#  764: 'big',
#  765: 'every',
#  766: 'PEOPLE',
#  767: 'hottest',
#  768: 'Everything',
#  769: 'can',
#  770: 'occasions',
#  771: 'truffle',
#  772: 'patty',
#  773: 'Went',
#  774: 'climbing',
#  775: 'RI',
#  776: 'fuzzy',
#  777: 'welcome',
#  778: 'crust',
#  779: 'tastings',
#  780: 'Mediterranean',
#  781: 'experienced',
#  782: 'find',
#  783: 'High-quality',
#  784: 'ordered',
#  785: 'Waited',
#  786: 'onion',
#  787: 'easily',
#  788: 'T.',
#  789: 'living',
#  790: 'Bay',
#  791: 'hearts',
#  792: 'check',
#  793: 'kid',
#  794: 'me',
#  795: 'but',
#  796: 'comfortable',
#  797: 'Ordered',
#  798: 'dinner',
#  799: 'bloodiest',
#  800: 'Japanese',
#  801: 'drastically',
#  802: 'bigger',
#  803: 'giving',
#  804: 'Ha',
#  805: 'well',
#  806: 'happier',
#  807: 'us',
#  808: ',',
#  809: 'mind',
#  810: 'exactly',
#  811: '23',
#  812: 'yummy',
#  813: 'Large',
#  814: 'AZ',
#  815: 'beauty',
#  816: 'humiliated',
#  817: 'ravoli',
#  818: 'cooked',
#  819: 'edible',
#  820: 'usual',
#  821: 'Ample',
#  822: 'highly',
#  823: 'simply',
#  824: 'deal',
#  825: 'different',
#  826: 'generic',
#  827: 'money',
#  828: 'crazy',
#  829: 'southwest',
#  830: 'worries',
#  831: 'restaurants',
#  832: 'around',
#  833: 'slaw',
#  834: 'Breeze',
#  835: 'family',
#  836: 'voted',
#  837: 'hand',
#  838: 'degree',
#  839: 'Thus',
#  840: 'looks',
#  841: 'Hell',
#  842: 'rapidly',
#  843: 'rushed',
#  844: 'in',
#  845: 'Those',
#  846: 'store',
#  847: 'than',
#  848: 'Best',
#  849: 'Now',
#  850: 'fat',
#  851: 'Which',
#  852: 'places',
#  853: 'Every',
#  854: 'salmon',
#  855: 'Im',
#  856: 'Before',
#  857: 'handmade',
#  858: 'ignore',
#  859: 'businesses',
#  860: 'honestly',
#  861: 'services',
#  862: 'boring',
#  863: 'Otto',
#  864: 'biscuit',
#  865: 'tuna',
#  866: 'events',
#  867: 'low',
#  868: 'pulled',
#  869: 'sliced',
#  870: 'gooodd',
#  871: 'garlic',
#  872: 'courteous',
#  873: 'perfect',
#  874: 'fries',
#  875: 'cheap',
#  876: 'Nicest',
#  877: 'loyal',
#  878: 'plain',
#  879: 'Perfect',
#  880: 'high',
#  881: 'running',
#  882: 'piece',
#  883: 'joint',
#  884: 'Blah',
#  885: 'sporting',
#  886: 'NOW',
#  887: 'class',
#  888: 'shoots',
#  889: 'highlights',
#  890: 'cheated',
#  891: 'bathrooms',
#  892: 'rest',
#  893: 'Food',
#  894: 'gristle',
#  895: 'appetizers',
#  896: 'shirt',
#  897: 'Sour',
#  898: 'yukon',
#  899: 'accomodate',
#  900: 'generous',
#  901: 'My',
#  902: 'relocated',
#  903: 'entire',
#  904: 'let',
#  905: 'peanuts',
#  906: 'fireball',
#  907: 'sucks',
#  908: 'looked',
#  909: 'bruschetta',
#  910: 'obviously',
#  911: 'Prices',
#  912: 'par',
#  913: 'Philadelphia',
#  914: 'papers',
#  915: 'pasta',
#  916: 'Cibo',
#  917: 'From',
#  918: 'May',
#  919: 'pumpkin',
#  920: 'MGM',
#  921: 'struck',
#  922: 'Albondigas',
#  923: 'point',
#  924: '1.5lb',
#  925: 'dirt',
#  926: 'fell',
#  927: 'beef',
#  928: 'haunt',
#  929: '%',
#  930: 'Damn',
#  931: 'order',
#  932: 'lil',
#  933: 'Gave',
#  934: 'This',
#  935: 'Avoid',
#  936: 'imagined',
#  937: '.',
#  938: 'Each',
#  939: 'AN',
#  940: 'melted',
#  941: 'juice..',
#  942: 'meh',
#  943: 'die',
#  944: 'enthusiastic',
#  945: 'seating',
#  946: 'sandwiches',
#  947: 'Interesting',
#  948: 'waiter',
#  949: 'officially',
#  950: 'food/service',
#  951: 'liked',
#  952: 'Magazine',
#  953: 'door',
#  954: 'takeout',
#  955: 'deliciously',
#  956: 'box',
#  957: 'street',
#  958: 'lacked',
#  959: 'fairly',
#  960: 'flavourful',
#  961: 'Maine',
#  962: 'packed',
#  963: 'parents',
#  964: 'Try',
#  965: 'about',
#  966: 'Smashburger',
#  967: 'attack',
#  968: 'her',
#  969: 'pleased',
#  970: 'appalling',
#  971: 'stars',
#  972: 'bone',
#  973: 'spinach',
#  974: '15',
#  975: 'patron',
#  976: 'dish',
#  977: 'An',
#  978: 'outside',
#  979: 'HOUR',
#  980: 'correction',
#  981: 'Dessert',
#  982: 'All',
#  983: 'Excalibur',
#  984: 'town',
#  985: 'excellent',
#  986: 'toasted',
#  987: 'both',
#  988: 'sugary',
#  989: 'Plater',
#  990: 'play',
#  991: 'lettuce',
#  992: 'forth',
#  993: 'Only',
#  994: 'Mirage',
#  995: 'could',
#  996: 'Mmmm',
#  997: 'out',
#  998: 'meatballs',
#  999: 'under',
#  ...}

# %%
#轉換句子為bag of words型式
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    #我們先建造一個 len(whole_words)維，數值皆為 0 的向量 (ex.[0, 0, 0,......])
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            #將這個評價內有出現的單詞取出，找到對應的 index，將向量中這個位置的值 +1
            vector[word_index[word]]+=1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
#array([0., 0., 0., ..., 0., 0., 0.])
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
_get_bag_of_words_vector('Crust is not good.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
